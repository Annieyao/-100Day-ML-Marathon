# %% [markdown]
# 作業1
# 選擇資料：Brazilian E-Commerce Public Dataset by Olist
# 1. 你選的這組資料為何重要
# 可以了解巴西店商客戶行為模式與消費習慣
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
# 提供者為巴西Olist電子商務網站，資料蒐集自其購物網站Olist Store： www.olist.com
# 3. 蒐集而來的資料型態為何
# 資料型態包含數值類型與文字類型
# 4. 這組資料想解決的問題如何評估
# 集群分析

# %% [markdown]
# 作業2：
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
# 目標在於提升業績，在假設資料庫完整下，我們可以定義提升業績為月載客量成長率，若連續3個月成長率皆為正則可代表業績穩定成長
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
# 日載客量、月載客量、季載客量、載客時段、載客里程與收費、載客地點與下車地點，這些資料可以幫助我們分析熱門載客點與時段，有利日後進行載客量預測與行銷
# 3. 蒐集而來的資料型態為何
# 蒐集之資料型態為數值資料、文字資料
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
# 可利用迴歸分析、F Test

# %%
作業3：
統計指標實作範例
常見於迴歸問題的評估指標
Mean Absolute Error (MAE)
Mean Squared Error (MSE)
常見於分類問題的指標
Binary Cross Entropy (CE)
後面的課程還會有更詳細的說明

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

MAE = mean_absolute_error(y, y_hat)
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean absolute error is 13.186

# %%
##練習時間
def mean_square_error(y, yp):
    mse = MSE = (sum(abs(y - yp)) / len(y))**2
    return mse

MSE = mean_square_error(y, y_hat)
print("The Mean square error is %.3f" % (MSE))
# Out:
# The Mean square error is 173.863
